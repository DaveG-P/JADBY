# %% [markdown]
# # Before Getting Started

# %%
# Dependencies
import pandas as pd
import folium

# %%
# Mapping test of one park (e.g. Grand Canyon of the yellowstone: 61.4182147,-142.6028439)
folium_map = folium.Map(location=[61.4182147,-142.6028439])
marker = folium.Marker([61.4182147,-142.6028439], 
         popup='Grand Canyon of the Yellowstone').add_to(folium_map)

# Display map
folium_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Processing National Parks Data

# %% [markdown]
# ## Pre-Processing Data

# %% [markdown]
# ### 1. To get started, create a DataFrame containing the location of each national park

# %%
# Load data collected from national park information.
parks_data = pd.read_csv("top10parks_by_Winter.csv")

# Display the DataFrame generated from loaded data
parks_data.head()
# Out:
#                          Park Date of Review  Rating  Total Number of Reviews  \
# 0  Arches National Park, Utah    Dec 10,2017       2                       36
# 1  Arches National Park, Utah    Feb 26,2017       2                       36
# 2  Arches National Park, Utah     Ja 23,2017       2                       36
# 3  Arches National Park, Utah     Dec 3,2017       2                       15
# 4  Arches National Park, Utah    Jan 23,2017       2                       15
#
#    Aggregate State,USA only  Country  Age Gender (M or F)  \
# 0        4.9         Georgia     USA   11               M
# 1        4.9        Tennesse     USA    6               M
# 2        4.9        Virginia     USA   29               F
# 3        4.9        New York     USA   63               M
# 4        4.9           Idaho     USA   38               M
#
#   Relationship (Couple or Single)  Occupation         Top Activity  Season
# 0                         Married      494776  Delicate Arch Visit  winter
# 1                         Married      457545  Delicate Arch Visit  winter
# 2                         Married      132621  Delicate Arch Visit  winter
# 3                          Single      138321  Delicate Arch Visit  winter
# 4                          Single      467195  Delicate Arch Visit  winter

# %%
# Load coordinate data of each national park.
parks_coord = pd.read_csv("parks_coord.csv")

# Display the DataFrame generated from loaded data
parks_coord.head()
# Out:
#                                       Park  Latitude  Longitude
# 0               Arches National Park, Utah   38.7331    -109.59
# 1  Mount Rainier National Park, Washington   46.8800    -121.73
# 2         Bryce Canyon National Park, Utah   37.5930    -112.19
# 3       Yosemite National Park, California   37.8651    -119.54
# 4             Denali National Park, Alaska   63.1148    -151.19

# %%
# Merging data
parks_df = pd.merge(parks_data, parks_coord, on='Park')

# Display the DataFrame generated from merged data
parks_df
# Out:
#                                          Park Date of Review  Rating  \
# 0                  Arches National Park, Utah    Dec 10,2017       2
# 1                  Arches National Park, Utah    Feb 26,2017       2
# 2                  Arches National Park, Utah     Ja 23,2017       2
# 3                  Arches National Park, Utah     Dec 3,2017       2
# 4                  Arches National Park, Utah    Jan 23,2017       2
# 5            Bryce Canyon National Park, Utah    Dec 26,2017       5
# 6            Bryce Canyon National Park, Utah    Dec 26,2017       5
# 7            Bryce Canyon National Park, Utah    Dec 17,2017       5
# 8            Bryce Canyon National Park, Utah    Dec 23,2017       5
# 9            Bryce Canyon National Park, Utah    Feb 15,2017       5
# 10         Yosemite National Park, California    Dec 17,2017       2
# 11         Yosemite National Park, California    Feb 15,2017       2
# 12         Yosemite National Park, California    Jan 14,2017       2
# 13         Yosemite National Park, California    jan 11,2017       2
# 14         Yosemite National Park, California     Jan 4,2017       2
# 15               Denali National Park, Alaska    Dec 31,2017       5
# 16               Denali National Park, Alaska    Dec 16,2017       5
# 17               Denali National Park, Alaska    Feb 13,2017       5
# 18               Denali National Park, Alaska    Jan 21,2017       5
# 19               Denali National Park, Alaska     Jan 7,2017       5
# 20        Grand Canyon National Park, Arizona    Dec 30,2017       5
# 21        Grand Canyon National Park, Arizona    Dec 27,2017       5
# 22        Grand Canyon National Park, Arizona    Dec 26,2017       5
# 23        Grand Canyon National Park, Arizona    Dec 10,2017       5
# 24        Grand Canyon National Park, Arizona     Dec 4,2017       5
# 25         Yellowstone National Park, Wyoming    Dec 18,2017       2
# 26         Yellowstone National Park, Wyoming    Feb 15,2017       2
# 27         Yellowstone National Park, Wyoming    Jan 26,2017       2
# 28         Yellowstone National Park, Wyoming    Feb 23,2017       2
# 29         Yellowstone National Park, Wyoming    Feb 15,2017       2
# 30     Rocky Mountain National Park, Colorado    Dec 17,2017       5
# 31     Rocky Mountain National Park, Colorado    Feb 13,2017       5
# 32     Rocky Mountain National Park, Colorado     Jan 4,2017       5
# 33     Rocky Mountain National Park, Colorado    Feb 14,2017       5
# 34     Rocky Mountain National Park, Colorado     Jan 1,2017       5
# 35  Lassen Volcanic National Park, California    Feb 20,2017       5
# 36  Lassen Volcanic National Park, California   Dec 24,20155       5
# 37  Lassen Volcanic National Park, California    Dec 24,2014       5
# 38  Lassen Volcanic National Park, California    Feb 22,2014       3
# 39  Lassen Volcanic National Park, California    Feb 14,2014       5
# 40                         Zion National Park    Feb 20,2016       5
# 41                         Zion National Park    Feb 10,2016       5
# 42                         Zion National Park    Dec 12.2017       5
# 43                         Zion National Park     Feb 6,2016       5
# 44                         Zion National Park    Feb 10,2018       5
#
#     Total Number of Reviews  Aggregate State,USA only  Country  Age  \
# 0                        36       4.90         Georgia     USA   11
# 1                        36       4.90        Tennesse     USA    6
# 2                        36       4.90        Virginia     USA   29
# 3                        15       4.90        New York     USA   63
# 4                        15       4.90           Idaho     USA   38
# 5                       153       4.90      New jersey     USA   30
# 6                       153       4.90           Texas     USA   30
# 7                       153       4.90        Missouri     USA   45
# 8                        21       4.90    pennsylvenia     USA   58
# 9                        21       4.90         Florida     USA   12
# 10                       66       4.90      California     USA   59
# 11                       66       4.90        Michigan     USA   81
# 12                       66       4.90      California     USA   44
# 13                       14       4.90            Utah     USA   63
# 14                       14       4.90          oregon     USA    9
# 15                       27       4.90        Tennesse     USA   71
# 16                       27       4.90       Minnesota     USA   10
# 17                       27       4.90  North Carolina     USA   21
# 18                       27       4.90        Michigan     USA    5
# 19                       27       4.90           Texas     USA   64
# 20                      833       4.90           Texas     USA   43
# 21                      833       4.90        Illinois     USA   22
# 22                      833       4.90         Florida     USA   69
# 23                       96       4.90         Florida     USA   15
# 24                       96       4.90            Utah     USA   27
# 25                       15       4.90        New York     USA   38
# 26                       86       4.90          Oregon     USA   34
# 27                       16       4.90      california     USA   28
# 28                        9       4.90           Idaho     USA   93
# 29                       86       4.90        New York     USA   97
# 30                       34       4.90        Michigan     USA   30
# 31                       34       4.90       Minnesota     USA   28
# 32                       34       4.90         Florida     USA    1
# 33                        5       4.90        Colorado     USA   26
# 34                       34       4.90      california     USA   66
# 35                        5       4.90            ohio     USA   57
# 36                        5       4.99      California     USA   25
# 37                        5       4.99      California     USA    7
# 38                        5       2.99           Texas     USA    3
# 39                        5       4.99      California     USA   64
# 40                       41       4.99  North Carolina     USA   50
# 41                       41       4.99      California     USA   56
# 42                       12       4.99      California     USA   38
# 43                       12       4.99         Arizona     USA   38
# 44                       12       4.99            Utah     USA   95
#
#    Gender (M or F) Relationship (Couple or Single)  Occupation  \
# 0                M                         Married      494776
# 1                M                         Married      457545
# 2                F                         Married      132621
# 3                M                          Single      138321
# 4                M                          Single      467195
# 5                F                         Married      203736
# 6                M                         Married      275290
# 7                F                         Married      452638
# 8                M                          Single      178474
# 9                F                          Single      430654
# 10               M                         Married      274108
# 11               M                         Married       87165
# 12               M                         Married      237117
# 13               F                          Single      107574
# 14               F                          Single      215582
# 15               M                         Married       57914
# 16               M                         Married      480712
# 17               F                         Married      407586
# 18               F                         Married      148228
# 19               M                         Married      421048
# 20               M                         Married      289272
# 21               M                         Married      185618
# 22               F                         Married      232514
# 23               F                          Single      347434
# 24               M                          Single      323765
# 25               M                         Married      103907
# 26               F                         Married      184566
# 27               M                         Married      477975
# 28               M                          Single      306312
# 29               F                         Married      206876
# 30               F                         Married      399116
# 31               F                         Married      113495
# 32               F                         Married      399445
# 33               M                          Single      179744
# 34               F                         Married      297285
# 35               M                          Single      469391
# 36               F                          Single      145027
# 37               F                          Single      274779
# 38               M                          Single      184799
# 39               M                          Single      377814
# 40               F                         Married      455531
# 41               F                         Married      140679
# 42               F                          Single      477426
# 43               M                          Single      494663
# 44               F                          Single      466331
#
#                         Top Activity  Season  Latitude  Longitude
# 0                Delicate Arch Visit  winter   38.7331    -109.59
# 1                Delicate Arch Visit  winter   38.7331    -109.59
# 2                Delicate Arch Visit  winter   38.7331    -109.59
# 3                Delicate Arch Visit  winter   38.7331    -109.59
# 4                Delicate Arch Visit  winter   38.7331    -109.59
# 5         Bryce Canyon National Park  winter   37.5930    -112.19
# 6         Bryce Canyon National Park  winter   37.5930    -112.19
# 7         Bryce Canyon National Park  winter   37.5930    -112.19
# 8         Bryce Canyon National Park  winter   37.5930    -112.19
# 9         Bryce Canyon National Park  winter   37.5930    -112.19
# 10                     Glacier Point  winter   37.8651    -119.54
# 11                     Glacier Point  winter   37.8651    -119.54
# 12                     Glacier Point  winter   37.8651    -119.54
# 13                     Glacier Point  winter   37.8651    -119.54
# 14                     Glacier Point  winter   37.8651    -119.54
# 15                            Denali  winter   63.1148    -151.19
# 16                            Denali  winter   63.1148    -151.19
# 17                            Denali  winter   63.1148    -151.19
# 18                            Denali  winter   63.1148    -151.19
# 19                            Denali  winter   63.1148    -151.19
# 20            Grand Canyon South Rim  winter   36.1070    -112.11
# 21            Grand Canyon South Rim  winter   36.1070    -112.11
# 22            Grand Canyon South Rim  winter   36.1070    -112.11
# 23            Grand Canyon South Rim  winter   36.1070    -112.11
# 24            Grand Canyon South Rim  winter   36.1070    -112.11
# 25  Grand Canyon of the yellowstone   winter   44.4280    -110.59
# 26  Grand Canyon of the yellowstone   winter   44.4280    -110.59
# 27  Grand Canyon of the yellowstone   winter   44.4280    -110.59
# 28  Grand Canyon of the yellowstone   winter   44.4280    -110.59
# 29  Grand Canyon of the yellowstone   winter   44.4280    -110.59
# 30                  Trail Ridge Road  winter   40.3428    -105.68
# 31                  Trail Ridge Road  winter   40.3428    -105.68
# 32                  Trail Ridge Road  winter   40.3428    -105.68
# 33                  Trail Ridge Road  winter   40.3428    -105.68
# 34                  Trail Ridge Road  winter   40.3428    -105.68
# 35                      Mount Lassen  winter   40.4977    -121.42
# 36                      Mount Lassen  winter   40.4977    -121.42
# 37                      Mount Lassen  winter   40.4977    -121.42
# 38                      Mount Lassen  winter   40.4977    -121.42
# 39                      Mount Lassen  winter   40.4977    -121.42
# 40               Zion's Main Canyon   winter   37.2982    -113.03
# 41               Zion's Main Canyon   winter   37.2982    -113.03
# 42               Zion's Main Canyon   winter   37.2982    -113.03
# 43               Zion's Main Canyon   winter   37.2982    -113.03
# 44               Zion's Main Canyon   winter   37.2982    -113.03

# %%
# Select the first occurrence of each station id.
parks_df = parks_df.groupby("Park").first()

# Display the new DataFrame
parks_df.head()
# Out:
#                                           Date of Review  Rating  \
# Park
# Arches National Park, Utah                   Dec 10,2017       2
# Bryce Canyon National Park, Utah             Dec 26,2017       5
# Denali National Park, Alaska                 Dec 31,2017       5
# Grand Canyon National Park, Arizona          Dec 30,2017       5
# Lassen Volcanic National Park, California    Feb 20,2017       5
#
#                                            Total Number of Reviews  Aggregate  \
# Park
# Arches National Park, Utah                                      36        4.9
# Bryce Canyon National Park, Utah                               153        4.9
# Denali National Park, Alaska                                    27        4.9
# Grand Canyon National Park, Arizona                            833        4.9
# Lassen Volcanic National Park, California                        5        4.9
#
#                                           State,USA only  Country  Age  \
# Park
# Arches National Park, Utah                        Georgia     USA   11
# Bryce Canyon National Park, Utah               New jersey     USA   30
# Denali National Park, Alaska                     Tennesse     USA   71
# Grand Canyon National Park, Arizona                 Texas     USA   43
# Lassen Volcanic National Park, California            ohio     USA   57
#
#                                           Gender (M or F)  \
# Park
# Arches National Park, Utah                              M
# Bryce Canyon National Park, Utah                        F
# Denali National Park, Alaska                            M
# Grand Canyon National Park, Arizona                     M
# Lassen Volcanic National Park, California               M
#
#                                           Relationship (Couple or Single)  \
# Park
# Arches National Park, Utah                                        Married
# Bryce Canyon National Park, Utah                                  Married
# Denali National Park, Alaska                                      Married
# Grand Canyon National Park, Arizona                               Married
# Lassen Volcanic National Park, California                          Single
#
#                                            Occupation  \
# Park
# Arches National Park, Utah                     494776
# Bryce Canyon National Park, Utah               203736
# Denali National Park, Alaska                    57914
# Grand Canyon National Park, Arizona            289272
# Lassen Volcanic National Park, California      469391
#
#                                                          Top Activity  Season  \
# Park
# Arches National Park, Utah                        Delicate Arch Visit  winter
# Bryce Canyon National Park, Utah           Bryce Canyon National Park  winter
# Denali National Park, Alaska                                   Denali  winter
# Grand Canyon National Park, Arizona            Grand Canyon South Rim  winter
# Lassen Volcanic National Park, California                Mount Lassen  winter
#
#                                            Latitude  Longitude
# Park
# Arches National Park, Utah                  38.7331    -109.59
# Bryce Canyon National Park, Utah            37.5930    -112.19
# Denali National Park, Alaska                63.1148    -151.19
# Grand Canyon National Park, Arizona         36.1070    -112.11
# Lassen Volcanic National Park, California   40.4977    -121.42

# %%
# Select Start Station Name, Latitude, and Longitude as columns in DataFrame
parks_df = parks_df.loc[:, ["Rating",
                            "Latitude",
                            "Longitude"]]
parks_df
# Out:
#                                            Rating  Latitude  Longitude
# Park
# Arches National Park, Utah                      2   38.7331    -109.59
# Bryce Canyon National Park, Utah                5   37.5930    -112.19
# Denali National Park, Alaska                    5   63.1148    -151.19
# Grand Canyon National Park, Arizona             5   36.1070    -112.11
# Lassen Volcanic National Park, California       5   40.4977    -121.42
# Rocky Mountain National Park, Colorado          5   40.3428    -105.68
# Yellowstone National Park, Wyoming              2   44.4280    -110.59
# Yosemite National Park, California              2   37.8651    -119.54
# Zion National Park                              5   37.2982    -113.03

# %% [markdown]
# ## Plotting Markers for Each Station

# %%
# Generate a map from one park location
parks_map = folium.Map(location=[61.4182147,-142.6028439],
                        zoom_start=2.9,
                        width='100%')

# Display map
parks_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Extract the location, name, and rating information for each park
for index, row in parks_df.iterrows():
    rating = row['Rating']
    lat = row['Latitude']
    lon = row['Longitude']
    
    if rating < 3:
        index = folium.Icon(color='red')
    else:
        index = folium.Icon(color='green')

    #popup = folium.Popup(labels[row], parse_html=True)
    folium.Marker([lat, lon], popup='Rating' , icon = index).add_to(parks_map)    
    
# Create the html file with the map:
parks_map.save(outfile='parks_map.html')

# Display map
parks_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
